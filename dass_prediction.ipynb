# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhant-shekhar/AnuYog-v2/blob/main/dass_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What data do we have

# %% [markdown]
# This data was collected with an on-line version of the Depression Anxiety Stress Scales (DASS), see http://www2.psy.unsw.edu.au/dass/
#
#
# The survey was open to anyone and people were motivated to take it to get personalized results. At the end of the test they also were given the option to complete a short research survey. This datatset comes from those who agreed to complete the research survey and answered yes to the question "Have you given accurate answers and may they be used for research?" at the end.
#
#
# **This data was collected 2017 - 2019.**
#
#
# The following items were included in the survey:
#
# Q1	I found myself getting upset by quite trivial things.
#
# Q2	I was aware of dryness of my mouth.
#
# Q3	I couldn't seem to experience any positive feeling at all.
#
# Q4	I experienced breathing difficulty (eg, excessively rapid breathing,
# breathlessness in the absence of physical exertion).
#
# Q5	I just couldn&#39;t seem to get going.
#
# Q6	I tended to over-react to situations.
#
# Q7	I had a feeling of shakiness (eg, legs going to give way).
#
# Q8	I found it difficult to relax.
#
# Q9	I found myself in situations that made me so anxious I was most relieved when they ended.
#
# Q10	I felt that I had nothing to look forward to.
#
# Q11	I found myself getting upset rather easily.
#
# Q12	I felt that I was using a lot of nervous energy.
#
# Q13	I felt sad and depressed.
#
# Q14	I found myself getting impatient when I was delayed in any way (eg, elevators, traffic lights, being kept waiting).
#
# Q15	I had a feeling of faintness.
#
# Q16	I felt that I had lost interest in just about everything.
#
# Q17	I felt I wasn&#39;t worth much as a person.
#
# Q18	I felt that I was rather touchy.
#
# Q19	I perspired noticeably (eg, hands sweaty) in the absence of high
# temperatures or physical exertion.
#
# Q20	I felt scared without any good reason.
#
# Q21	I felt that life wasn&#39;t worthwhile.
#
# Q22	I found it hard to wind down.
#
# Q23	I had difficulty in swallowing.
#
# Q24	I couldn&#39;t seem to get any enjoyment out of the things I did.
#
# Q25	I was aware of the action of my heart in the absence of physical exertion (eg, sense of heart rate increase, heart missing a beat).
#
# Q26	I felt down-hearted and blue.
#
# Q27	I found that I was very irritable.
#
# Q28	I felt I was close to panic.
#
# Q29	I found it hard to calm down after something upset me.
#
# Q30	I feared that I would be &quot;thrown&quot; by some trivial but unfamiliar task.
#
# Q31	I was unable to become enthusiastic about anything.
#
# Q32	I found it difficult to tolerate interruptions to what I was doing.
#
# Q33	I was in a state of nervous tension.
#
# Q34	I felt I was pretty worthless.
#
# Q35	I was intolerant of anything that kept me from getting on with what I was doing.
#
# Q36	I felt terrified.
#
# Q37	I could see nothing in the future to be hopeful about.
#
# Q38	I felt that life was meaningless.
#
# Q39	I found myself getting agitated.
#
# Q40	I was worried about situations in which I might panic and make a fool of
# myself.
#
# Q41	I experienced trembling (eg, in the hands).
#
# Q42	I found it difficult to work up the initiative to do things.
#
#
# Each item was presented one at a time in a random order for each new participant along with a 4 point rating scale asking the user to indicate how often that had been true of them in the past week where
#
# 1 = Did not apply to me at all
#
# 2 = Applied to me to some degree, or some of the time
#
# 3 = Applied to me to a considerable degree, or a good part of the time
#
# 4 = Applied to me very much, or most of the time
#
# (see the file demo1.png for how this looked)
#
# This response is stored in variable A (e.g. Q1A). Also recorded was the time taken in milliseconds to answer that question (E) and that question's position in the survey (I).
#
# These other durations were also recorded (measured on the server's side):
#
# introelapse		The time spent on the introduction/landing page (in seconds)
#
# testelapse		The time spent on all the DASS questions (should be equivalent to
# the time elapsed on all the indiviudal questions combined)
#
# surveyelapse	The time spent answering the rest of the demographic and survey questions
#
# On the next page was a generic demographics survey with many different questions.
#
# The Ten Item Personality Inventory was administered (see Gosling, S. D., Rentfrow, P. J., & Swann, W. B., Jr. (2003). A Very Brief Measure of the Big Five Personality Domains. Journal of Research in Personality, 37, 504-528.):
#
# TIPI1	Extraverted, enthusiastic.
#
# TIPI2	Critical, quarrelsome.
#
# TIPI3	Dependable, self-disciplined.
#
# TIPI4	Anxious, easily upset.
#
# TIPI5	Open to new experiences, complex.
#
# TIPI6	Reserved, quiet.
#
# TIPI7	Sympathetic, warm.
#
# TIPI8	Disorganized, careless.
#
# TIPI9	Calm, emotionally stable.
#
# TIPI10	Conventional, uncreative.
#
#
# The TIPI items were rated "I see myself as:" _____ such that
#
# 1 = Disagree strongly
#
# 2 = Disagree moderately
#
# 3 = Disagree a little
#
# 4 = Neither agree nor disagree
#
# 5 = Agree a little
#
# 6 = Agree moderately
#
# 7 = Agree strongly
#
#
#
# The following items were presented as a check-list and subjects were instructed "In the grid below, check all the words whose definitions you are sure you know":
#
# VCL1	boat
#
# VCL2	incoherent
#
# VCL3	pallid
#
# VCL4	robot
#
# VCL5	audible
#
# VCL6	cuivocal
#
# VCL7	paucity
#
# VCL8	epistemology
#
# VCL9	florted
#
# VCL10	decide
#
# VCL11	pastiche
#
# VCL12	verdid
#
# VCL13	abysmal
#
# VCL14	lucid
#
# VCL15	betray
#
# VCL16	funny
#
# A value of 1 is checked, 0 means unchecked. The words at VCL6, VCL9, and VCL12 are not real words and can be used as a validity check.
#
# A bunch more questions were then asked:
#
#
# education			"How much education have you completed?", 1=Less than high school, 2=High school, 3=University degree, 4=Graduate degree
#
# urban				"What type of area did you live when you were a child?", 1=Rural (country side), 2=Suburban, 3=Urban (town, city)
#
# gender				"What is your gender?", 1=Male, 2=Female, 3=Other
#
# engnat				"Is English your native language?", 1=Yes, 2=No
#
# age					"How many years old are you?"
#
# hand				"What hand do you use to write with?", 1=Right, 2=Left, 3=Both
#
# religion			"What is your religion?", 1=Agnostic, 2=Atheist, 3=Buddhist,
# 4=Christian (Catholic), 5=Christian (Mormon), 6=Christian (Protestant), 7=Christian (Other), 8=Hindu, 9=Jewish, 10=Muslim, 11=Sikh, 12=Other
#
# orientation			"What is your sexual orientation?", 1=Heterosexual, 2=Bisexual, 3=Homosexual, 4=Asexual, 5=Other
#
# race				"What is your race?", 10=Asian, 20=Arab, 30=Black, 40=Indigenous Australian, 50=Native American, 60=White, 70=Other
#
# voted				"Have you voted in a national election in the past year?", 1=Yes, 2=No
#
# married				"What is your marital status?", 1=Never married, 2=Currently married, 3=Previously married
#
# familysize			"Including you, how many children did your mother have?"
#
# major				"If you attended a university, what was your major (e.g. "psychology", "English", "civil engineering")?"
#
# The following values were derived from technical information:
#
# country				ISO country code of where the user connected from
#
# screensize			1=device with small screen (phone, etc), 2=device with big screen (laptop, desktop, etc)
#
# uniquenetworklocation		1=only one survey from user's specific network in dataset, 2=multiple surveys submitted from the network of this user  (2 does not necessarily imply duplicate records for an individual, as it could be different students at a single school or different memebers of the same household; and even if 1 there still could be duplicate records from a single individual e.g. if they took it once on their wifi and once on their phone)
#
# source			how the user found the test, 1=from the front page of the site hosting the survey, 2=from google, 0=other or unknown

# %% [markdown]
# # Library import and reading data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
with warnings.catch_warnings():
    warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/dass_data.csv', delimiter='\t')

# %%
df.head()
# Out:
#    Q1A  Q1I   Q1E  Q2A  Q2I   Q2E  Q3A  Q3I   Q3E  Q4A  ...  screensize  \
# 0    4   28  3890    4   25  2122    2   16  1944    4  ...           1
# 1    4    2  8118    1   36  2890    2   35  4777    3  ...           2
# 2    3    7  5784    1   33  4373    4   41  3242    1  ...           2
# 3    2   23  5081    3   11  6837    2   37  5521    1  ...           2
# 4    2   36  3215    2   13  7731    3    5  4156    4  ...           2
#
#    uniquenetworklocation  hand  religion  orientation  race  voted  married  \
# 0                      1     1        12            1    10      2        1
# 1                      1     2         7            0    70      2        1
# 2                      1     1         4            3    60      1        1
# 3                      1     2         4            5    70      2        1
# 4                      2     3        10            1    10      2        1
#
#    familysize       major
# 0           2         NaN
# ...

# %%
df.shape
# Out:
# (39775, 172)

# %%
df.columns.to_list()
# Out:
# ['Q1A',
#  'Q1I',
#  'Q1E',
#  'Q2A',
#  'Q2I',
#  'Q2E',
#  'Q3A',
#  'Q3I',
#  'Q3E',
#  'Q4A',
#  'Q4I',
#  'Q4E',
#  'Q5A',
#  'Q5I',
#  'Q5E',
#  'Q6A',
#  'Q6I',
#  'Q6E',
#  'Q7A',
#  'Q7I',
#  'Q7E',
#  'Q8A',
#  'Q8I',
#  'Q8E',
#  'Q9A',
#  'Q9I',
#  'Q9E',
#  'Q10A',
#  'Q10I',
#  'Q10E',
#  'Q11A',
#  'Q11I',
#  'Q11E',
#  'Q12A',
#  'Q12I',
#  'Q12E',
#  'Q13A',
#  'Q13I',
#  'Q13E',
#  'Q14A',
#  'Q14I',
#  'Q14E',
#  'Q15A',
#  'Q15I',
#  'Q15E',
#  'Q16A',
#  'Q16I',
#  'Q16E',
#  'Q17A',
#  'Q17I',
#  'Q17E',
#  'Q18A',
#  'Q18I',
#  'Q18E',
#  'Q19A',
#  'Q19I',
#  'Q19E',
#  'Q20A',
#  'Q20I',
#  'Q20E',
#  'Q21A',
#  'Q21I',
#  'Q21E',
#  'Q22A',
#  'Q22I',
#  'Q22E',
#  'Q23A',
#  'Q23I',
#  'Q23E',
#  'Q24A',
#  'Q24I',
#  'Q24E',
#  'Q25A',
#  'Q25I',
#  'Q25E',
#  'Q26A',
#  'Q26I',
#  'Q26E',
#  'Q27A',
#  'Q27I',
#  'Q27E',
#  'Q28A',
#  'Q28I',
#  'Q28E',
#  'Q29A',
#  'Q29I',
#  'Q29E',
#  'Q30A',
#  'Q30I',
#  'Q30E',
#  'Q31A',
#  'Q31I',
#  'Q31E',
# ...

# %% [markdown]
# # Keeping only usefull data

# %% [markdown]
# we don't require that much of columns for our prediction, we will only keep the questions....

# %% [markdown]
# we only keep the following columns for our prediciton:-
# Q1A to Q42A
#
# TIPI1 to TIPI2 (ten item personality inventory)
#
# age
#
# gender
#
# education
#
# urban
#
# married
#
# familysize

# %%
# list of to be removed features from dataset
removedFeatures = [f'Q{i}E' for i in range(1, 43)] # feature 'Q1E' to 'Q42E' to be removed
removedFeatures.extend([f'Q{i}I' for i in range(1, 43)]) # feature 'Q1E' to 'Q42E' to be removed
removedFeatures.extend([f'VCL{i}' for i in range(1, 17)]) # feature 'VCL1' to 'VCL16' to be removed
removedFeatures.extend([ 'source', 'introelapse', 'testelapse', 'surveyelapse', 'engnat', 'hand', 'orientation',
    'voted', 'country', 'screensize', 'uniquenetworklocation', 'religion', 'major', 'race'])

# remove features from the dataset
new_data = df.drop(removedFeatures, axis=1)
new_data.head()
# Out:
#    Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...  TIPI7  TIPI8  \
# 0    4    4    2    4    4    4    4    4    2     1  ...      7      5
# 1    4    1    2    3    4    4    3    4    3     2  ...      7      7
# 2    3    1    4    1    4    3    1    3    2     4  ...      5      5
# 3    2    3    2    1    3    3    4    2    3     3  ...      6      1
# 4    2    2    3    4    4    2    4    4    4     3  ...      5      6
#
#    TIPI9  TIPI10  education  urban  gender  age  married  familysize
# 0      1       1          2      3       2   16        1           2
# 1      1       5          2      3       2   16        1           4
# 2      3       2          2      3       2   17        1           3
# 3      6       1          1      3       2   13        1           5
# 4      3       3          3      2       2   19        1           4
#
# [5 rows x 58 columns]

# %%
new_data.shape
# Out:
# (39775, 58)

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(new_data.isnull())
plt.show()

# %%
new_data.isnull().sum()
# Out:
# Q1A           0
# Q2A           0
# Q3A           0
# Q4A           0
# Q5A           0
# Q6A           0
# Q7A           0
# Q8A           0
# Q9A           0
# Q10A          0
# Q11A          0
# Q12A          0
# Q13A          0
# Q14A          0
# Q15A          0
# Q16A          0
# Q17A          0
# Q18A          0
# Q19A          0
# Q20A          0
# Q21A          0
# Q22A          0
# Q23A          0
# Q24A          0
# Q25A          0
# Q26A          0
# Q27A          0
# Q28A          0
# Q29A          0
# Q30A          0
# Q31A          0
# Q32A          0
# Q33A          0
# Q34A          0
# Q35A          0
# Q36A          0
# Q37A          0
# Q38A          0
# Q39A          0
# Q40A          0
# Q41A          0
# Q42A          0
# TIPI1         0
# TIPI2         0
# TIPI3         0
# TIPI4         0
# TIPI5         0
# TIPI6         0
# TIPI7         0
# TIPI8         0
# TIPI9         0
# TIPI10        0
# education     0
# urban         0
# gender        0
# ...

# %% [markdown]
# there is no null values present in the new_data

# %% [markdown]
# # Analyzing and cleaning each features except the questions

# %% [markdown]
# Now we will be going through the different features to analyze it and also to process it if any outliers or errors occurs in there

# %% [markdown]
# ## Education
# ### "How much education have you completed?"

# %%
new_data['education'].value_counts()
# Out:
# 3    15120
# 2    15066
# 4     5008
# 1     4066
# 0      515
# Name: education, dtype: int64

# %%
'''
    education "How much education have you completed?"
    1=Less than high school,
    2=High school,
    3=University degree,
    4=Graduate degree
'''

# combining 0 and 1 values as one value of 1 as they both are under less than high school

new_data['education'] = new_data['education'].map({ 0: 1,  1: 1, 2: 2, 3: 3, 4: 4 })

def changeEducationTitle(title) -> str:
    if title == 0 or title == 1:
        return 'Less than high school'
    if title == 2:
        return 'High school'
    if title == 3:
        return 'University degree'
    if title == 4:
        return 'Graduate degree'
    return title


# change education values form numbers to values to understand
education_string = new_data['education'].apply(changeEducationTitle)


plt.figure(figsize=(10, 5))
sns.countplot(x=new_data['education'], hue=education_string)
plt.show()

# %% [markdown]
# most of the people participated in the survey were in high school or in university

# %% [markdown]
# ## Urban
# ### "What type of area did you live when you were a child?"

# %%
new_data['urban'].value_counts()
# Out:
# 3    17843
# 2    13232
# 1     8318
# 0      382
# Name: urban, dtype: int64

# %%
'''
Urban Feature Values:
    1=Rural (country side),
    2=Suburban,
    3=Urban (town, city)
    0=None
'''

# changing 0 to 3 value as it's the most used one
new_data['urban'] = new_data['urban'].map({0: 3, 1: 1, 2: 2, 3: 3})

def changeUrbanValues(value):
    if value == 1:
        return 'Rural (country side)'
    if value == 2:
        return 'Suburban'
    if value == 3:  # if value is 0 means user don't entered this value and we assume he is urban as most records are
        return 'Urban (town, city)'
    return value

urban = new_data['urban'].apply(changeUrbanValues)

plt.figure(figsize=(10, 5))
sns.countplot(x=new_data['urban'], hue= urban)
# Out:
# <Axes: xlabel='urban', ylabel='count'>

# %% [markdown]
# most of the people participated in the survey are from urban region

# %% [markdown]
# ## Gender
# ### "What is your gender?"

# %%
new_data['gender'].value_counts()
# Out:
# 2    30367
# 1     8789
# 3      552
# 0       67
# Name: gender, dtype: int64

# %%
'''
Gender Feature Values
    0=None
    1=Male,
    2=Female,
    3=Other
'''

# changing value 0 to 2 as female are most recorded in new_data
new_data['gender'] = new_data['gender'].map({0: 2, 1: 1, 2: 2, 3: 3})

def changeGenderValue(value):
    if value == 1:
        return 'Male'
    if value == 2 or value == 0: # value = 0 means user didn't enter this value, we assume it's female as most records are
        return 'Female'
    return 'Other' # if 3 or 0 return other as value

gender = new_data['gender'].apply(changeGenderValue)

plt.figure(figsize=(10,5))
sns.countplot(x = new_data['gender'], hue=gender)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %% [markdown]
# most of the people who participated in the survey were females

# %% [markdown]
# ## Age
# ### "How many years old are you?"

# %%
new_data['age'].value_counts()
# Out:
# 20      3789
# 21      3535
# 19      3510
# 18      3046
# 22      3009
#         ...
# 89         1
# 1996       1
# 223        1
# 78         1
# 99         1
# Name: age, Length: 79, dtype: int64

# %%
# it seems like the data consists some outliers

# %%
plt.figure(figsize=(10, 5))
sns.boxenplot(x=new_data['age'])
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# let's remove the data above 80 years of age, as the people above 80  are cnsidered old enough

# %%
# remove age > 80 years old

age_indexes = new_data[new_data['age'] > 80]['age'].index

display(age_indexes) # figure out how many

# remove these indexes
print(f'new_data size before: {new_data.shape[0]}')
new_data.drop(age_indexes, axis=0, inplace=True)
print(f'new_data size after: {new_data.shape[0]}')
# Out:
# Int64Index([527, 5340, 10231, 10878, 14236, 14367, 21383, 24898, 30027, 33730,
#             34901],
#            dtype='int64')
# new_data size before: 39775
# new_data size after: 39764

# %%
plt.figure(figsize=(10,5))
sns.boxenplot(x=new_data['age'])
plt.title('age distribution')
plt.show()

# %%
def makeAgeGroup(value):
    if value <= 10:
        return 'Under 10'
    if  10 <= value <= 16:
        return 'Primary Children'
    if 17 <= value <= 21:
        return 'Secondary Children'
    if 21 <= value <= 35:
        return 'Adults'
    if 36 <= value <= 48:
        return 'Elder Adults'
    if value >= 49:
        return 'Older People'

age = new_data['age'].apply(makeAgeGroup)

plt.figure(figsize=(18, 7))
sns.countplot(x=new_data['age'], hue=age)
plt.show()

# %% [markdown]
# making different age groups for the better further calculations

# %%
def makeAgeGroupFeature(value):
    if value <= 10:
        return 1
    if  10 <= value <= 16:
        return 2
    if 17 <= value <= 21:
        return 3
    if 21 <= value <= 35:
        return 4
    if 36 <= value <= 48:
        return 5
    if value >= 49:
        return 6

new_data['age_group'] = new_data['age'].apply(makeAgeGroupFeature)

new_data.head()
# Out:
#    Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...  TIPI8  TIPI9  \
# 0    4    4    2    4    4    4    4    4    2     1  ...      5      1
# 1    4    1    2    3    4    4    3    4    3     2  ...      7      1
# 2    3    1    4    1    4    3    1    3    2     4  ...      5      3
# 3    2    3    2    1    3    3    4    2    3     3  ...      1      6
# 4    2    2    3    4    4    2    4    4    4     3  ...      6      3
#
#    TIPI10  education  urban  gender  age  married  familysize  age_group
# 0       1          2      3       2   16        1           2          2
# 1       5          2      3       2   16        1           4          2
# 2       2          2      3       2   17        1           3          3
# 3       1          1      3       2   13        1           5          2
# 4       3          3      2       2   19        1           4          3
#
# [5 rows x 59 columns]

# %% [markdown]
# now we will drop the age column

# %%
new_data.drop('age', axis=1, inplace=True)
new_data.head()
# Out:
#    Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...  TIPI7  TIPI8  \
# 0    4    4    2    4    4    4    4    4    2     1  ...      7      5
# 1    4    1    2    3    4    4    3    4    3     2  ...      7      7
# 2    3    1    4    1    4    3    1    3    2     4  ...      5      5
# 3    2    3    2    1    3    3    4    2    3     3  ...      6      1
# 4    2    2    3    4    4    2    4    4    4     3  ...      5      6
#
#    TIPI9  TIPI10  education  urban  gender  married  familysize  age_group
# 0      1       1          2      3       2        1           2          2
# 1      1       5          2      3       2        1           4          2
# 2      3       2          2      3       2        1           3          3
# 3      6       1          1      3       2        1           5          2
# 4      3       3          3      2       2        1           4          3
#
# [5 rows x 58 columns]

# %% [markdown]
# ## Married
# ### "What is your marital status?"

# %%
new_data['married'].value_counts()
# Out:
# 1    34124
# 2     4355
# 3     1090
# 0      195
# Name: married, dtype: int64

# %%
''' 1=Never married,
    2=Currently married,
    3=Previously married '''


def change0to1inMarried(value):
    if value == 0:
        return 1
    return value

# change 0 to 1 value as it is the most answered one
new_data['married'] = new_data['married'].apply(change0to1inMarried)

def changeMarriedValueToString(value):
    if value == 1:
        return 'Never married'
    if value == 2:
        return 'Currently married'
    if value == 3:
        return 'Previously married'
    return value

# change numbers to strings for better viz
married = new_data['married'].apply(changeMarriedValueToString)


plt.figure(figsize=(7, 5))
sns.countplot(x=new_data['married'], hue=married)
plt.show()

# %% [markdown]
# most of the participant were never married

# %% [markdown]
# ## Familysize
# ### "Including you, how many children did your mother have?"

# %%
new_data['familysize'].value_counts()
# Out:
# 3     9203
# 2     9016
# 4     7537
# 5     4829
# 1     2946
# 6     2449
# 7     1243
# 0     1124
# 8      676
# 9      331
# 10     195
# 11     109
# 12      56
# 13      19
# 14       8
# 15       6
# 16       5
# 17       3
# 62       1
# 99       1
# 54       1
# 65       1
# 26       1
# 24       1
# 19       1
# 21       1
# 23       1
# Name: familysize, dtype: int64

# %% [markdown]
# it seems here also outliers are present

# %%
plt.figure(figsize=(18, 5))
sns.distplot(x=new_data['familysize'])
plt.show()
# Out:
# <ipython-input-28-eb33dc7de0fc>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=new_data['familysize'])

# %%
new_data['familysize'].quantile(0.999)
# Out:
# 13.0

# %%
new_data[new_data['familysize']>13]['familysize'].count()
# Out:
# 31

# %% [markdown]
# 13 looks reasonable to remove

# %%
# removing reocrds that has family size more than 13
indexes = new_data[new_data['familysize'] > 13].index

# reomve these indexes from dataframe
print(f'Depression size before: {new_data.shape[0]}')
new_data = new_data.drop(indexes, axis=0)
print(f'Depression size after: {new_data.shape[0]}')
# Out:
# Depression size before: 39764
# Depression size after: 39733

# %%
plt.figure(figsize=(8, 5))
sns.histplot(x=new_data['familysize'])
plt.show()

# %%
new_data.head()
# Out:
#    Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...  TIPI7  TIPI8  \
# 0    4    4    2    4    4    4    4    4    2     1  ...      7      5
# 1    4    1    2    3    4    4    3    4    3     2  ...      7      7
# 2    3    1    4    1    4    3    1    3    2     4  ...      5      5
# 3    2    3    2    1    3    3    4    2    3     3  ...      6      1
# 4    2    2    3    4    4    2    4    4    4     3  ...      5      6
#
#    TIPI9  TIPI10  education  urban  gender  married  familysize  age_group
# 0      1       1          2      3       2        1           2          2
# 1      1       5          2      3       2        1           4          2
# 2      3       2          2      3       2        1           3          3
# 3      6       1          1      3       2        1           5          2
# 4      3       3          3      2       2        1           4          3
#
# [5 rows x 58 columns]

# %% [markdown]
# # Analyzing and cleaning TIPI Features

# %%
new_data.head()
# Out:
#    Q1A  Q2A  Q3A  Q4A  Q5A  Q6A  Q7A  Q8A  Q9A  Q10A  ...  TIPI7  TIPI8  \
# 0    4    4    2    4    4    4    4    4    2     1  ...      7      5
# 1    4    1    2    3    4    4    3    4    3     2  ...      7      7
# 2    3    1    4    1    4    3    1    3    2     4  ...      5      5
# 3    2    3    2    1    3    3    4    2    3     3  ...      6      1
# 4    2    2    3    4    4    2    4    4    4     3  ...      5      6
#
#    TIPI9  TIPI10  education  urban  gender  married  familysize  age_group
# 0      1       1          2      3       2        1           2          2
# 1      1       5          2      3       2        1           4          2
# 2      3       2          2      3       2        1           3          3
# 3      6       1          1      3       2        1           5          2
# 4      3       3          3      2       2        1           4          3
#
# [5 rows x 58 columns]

# %%
def changeFromToinTIPI(value, From, to):
    if value == From:
        return to
    return value


def changeTIPIValues(value):
    if value == 1:
        return 'Disagree strongly'
    if value == 2:
        return 'Disagree moderately'
    if value == 3:
        return 'Disagree a little'
    if value == 4:
        return 'Neither agree nor disagree'
    if value == 5:
        return 'Agree a little'
    if value == 6:
        return 'Agree moderately'
    if value == 7:
        return 'Agree strongly'

    return value

# %% [markdown]
# ## TIPI1
# ### I see myself as: Extraverted, enthusiastic

# %%
new_data['TIPI1'].value_counts()
# Out:
# 5    8407
# 1    6221
# 6    6043
# 4    5874
# 2    5598
# 3    4627
# 7    2479
# 0     484
# Name: TIPI1, dtype: int64

# %%
new_data['TIPI1'] = new_data['TIPI1'].apply(lambda value: changeFromToinTIPI(value, 0,5))

tipi = new_data['TIPI1'].apply(changeTIPIValues)

plt.figure(figsize=(10,5))
sns.countplot(x=new_data['TIPI1'], hue=tipi)
plt.show()

# %% [markdown]
# most people who choosed TIPI1 question aggreed a little and disagreed

# %% [markdown]
# ## TIPI2
# ### I see myself as: Critical, quarrelsome.

# %%
new_data['TIPI2'].value_counts()
# Out:
# 5    10367
# 6     6981
# 4     6165
# 3     4320
# 2     4036
# 1     3979
# 7     3316
# 0      569
# Name: TIPI2, dtype: int64

# %%
new_data['TIPI2'] = new_data['TIPI2'].apply(lambda value: changeFromToinTIPI(value, 0, 5))

tipi = new_data['TIPI2'].apply(changeTIPIValues)

plt.figure(figsize=(10,5))
sns.countplot(x=new_data['TIPI2'], hue=tipi)
# Out:
# <Axes: xlabel='TIPI2', ylabel='count'>

# %% [markdown]
# ## TIPI3
# ### I see myself as: Dependable, self-disciplined.

# %%
new_data['TIPI3'].value_counts()
# Out:
# 6    10215
# 5     9116
# 7     6231
# 4     4515
# 3     3978
# 2     2841
# 1     2248
# 0      589
# Name: TIPI3, dtype: int64

# %%
new_data['TIPI3'] = new_data['TIPI3'].apply(lambda value: changeFromToinTIPI(value, 0, 6))

tipi = new_data['TIPI3'].apply(changeTIPIValues)

plt.figure(figsize=(10,5))
sns.countplot(x=new_data['TIPI3'], hue=tipi)
# Out:
# <Axes: xlabel='TIPI3', ylabel='count'>

# %% [markdown]
# ## TIPI4

# %%
new_data['TIPI4'].value_counts()
# Out:
# 7    11348
# 6     9554
# 5     8740
# 4     2717
# 2     2441
# 3     2431
# 1     2039
# 0      463
# Name: TIPI4, dtype: int64

# %%
new_data['TIPI4'] = new_data['TIPI4'].apply(lambda value: changeFromToinTIPI(value, 0, 7))

tipi = new_data['TIPI4'].apply(changeTIPIValues)

plt.figure(figsize=(10,5))
sns.countplot(x=new_data['TIPI4'], hue=tipi)
# Out:
# <Axes: xlabel='TIPI4', ylabel='count'>

# %% [markdown]
# ## TIPI5

# %%
new_data['TIPI5'].value_counts()
# Out:
# 6    9686
# 5    9517
# 7    7675
# 4    5135
# 3    3336
# 2    2224
# 1    1644
# 0     516
# Name: TIPI5, dtype: int64

# %%
new_data['TIPI5'] = new_data['TIPI5'].apply(lambda value: changeFromToinTIPI(value, 0, 6))

tipi = new_data['TIPI5'].apply(changeTIPIValues)

plt.figure(figsize=(10,5))
sns.countplot(x=new_data['TIPI5'], hue=tipi)
# Out:
# <Axes: xlabel='TIPI5', ylabel='count'>

# %% [markdown]
# ## TIPI6

# %%
new_data['TIPI6'].value_counts()
# Out:
# 7    9611
# 6    8083
# 5    7729
# 4    4939
# 3    3472
# 2    2746
# 1    2663
# 0     490
# Name: TIPI6, dtype: int64

# %%
new_data['TIPI6'] = new_data['TIPI6'].apply(lambda value: changeFromToinTIPI(value, 0, 7))

tipi = new_data['TIPI6'].apply(changeTIPIValues)

plt.figure(figsize=(10,5))
sns.countplot(x=new_data['TIPI6'], hue=tipi)
# Out:
# <Axes: xlabel='TIPI6', ylabel='count'>

# %% [markdown]
# ## TIPI7

# %%
new_data['TIPI7'].value_counts()
# Out:
# 6    10989
# 7     9997
# 5     9087
# 4     4420
# 3     2266
# 2     1363
# 1     1011
# 0      600
# Name: TIPI7, dtype: int64

# %%
new_data['TIPI7'] = new_data['TIPI7'].apply(lambda value: changeFromToinTIPI(value, 0, 6))

tipi = new_data['TIPI7'].apply(changeTIPIValues)

plt.figure(figsize=(10,5))
sns.countplot(x=new_data['TIPI7'], hue=tipi)
# Out:
# <Axes: xlabel='TIPI7', ylabel='count'>

# %% [markdown]
# ## TIPI8

# %%
new_data['TIPI8'].value_counts()
# Out:
# 5    9296
# 6    6360
# 7    5834
# 4    4576
# 3    4438
# 2    4437
# 1    4134
# 0     658
# Name: TIPI8, dtype: int64

# %%
new_data['TIPI8'] = new_data['TIPI8'].apply(lambda value: changeFromToinTIPI(value, 0, 5))

tipi = new_data['TIPI8'].apply(changeTIPIValues)

plt.figure(figsize=(10,5))
sns.countplot(x=new_data['TIPI8'], hue=tipi)
# Out:
# <Axes: xlabel='TIPI8', ylabel='count'>

# %% [markdown]
# ## TIPI9

# %%
new_data['TIPI9'].value_counts()
# Out:
# 4    6832
# 3    6813
# 2    6395
# 5    6241
# 1    5500
# 6    4938
# 7    2588
# 0     426
# Name: TIPI9, dtype: int64

# %%
new_data['TIPI9'] = new_data['TIPI9'].apply(lambda value: changeFromToinTIPI(value, 0, 4))

tipi = new_data['TIPI9'].apply(changeTIPIValues)

plt.figure(figsize=(10,5))
sns.countplot(x=new_data['TIPI9'], hue=tipi)
# Out:
# <Axes: xlabel='TIPI9', ylabel='count'>

# %% [markdown]
# ## TIPI10

# %%
new_data['TIPI10'].value_counts()
# Out:
# 4    7658
# 5    6647
# 3    6175
# 2    5708
# 1    5400
# 6    4102
# 7    3489
# 0     554
# Name: TIPI10, dtype: int64

# %%
new_data['TIPI10'] = new_data['TIPI10'].apply(lambda value: changeFromToinTIPI(value, 0, 4))

tipi = new_data['TIPI10'].apply(changeTIPIValues)

plt.figure(figsize=(10,5))
sns.countplot(x=new_data['TIPI10'], hue=tipi)
# Out:
# <Axes: xlabel='TIPI10', ylabel='count'>

# %% [markdown]
# # Dividing into Depression, Anxiety and Stress for ***DASS-12*** questionnaire and building ml model

# %%
new_data.columns
# Out:
# Index(['Q1A', 'Q2A', 'Q3A', 'Q4A', 'Q5A', 'Q6A', 'Q7A', 'Q8A', 'Q9A', 'Q10A',
#        'Q11A', 'Q12A', 'Q13A', 'Q14A', 'Q15A', 'Q16A', 'Q17A', 'Q18A', 'Q19A',
#        'Q20A', 'Q21A', 'Q22A', 'Q23A', 'Q24A', 'Q25A', 'Q26A', 'Q27A', 'Q28A',
#        'Q29A', 'Q30A', 'Q31A', 'Q32A', 'Q33A', 'Q34A', 'Q35A', 'Q36A', 'Q37A',
#        'Q38A', 'Q39A', 'Q40A', 'Q41A', 'Q42A', 'TIPI1', 'TIPI2', 'TIPI3',
#        'TIPI4', 'TIPI5', 'TIPI6', 'TIPI7', 'TIPI8', 'TIPI9', 'TIPI10',
#        'education', 'urban', 'gender', 'married', 'familysize', 'age_group'],
#       dtype='object')

# %% [markdown]
# changing the score scheme:
#
# 1 --> 0
#
# 2 --> 1
#
# 3 --> 2
#
# 4 --> 3

# %%
new_data[['Q1A', 'Q2A', 'Q3A', 'Q4A', 'Q5A', 'Q6A', 'Q7A', 'Q8A', 'Q9A', 'Q10A', 'Q11A',
           'Q12A', 'Q13A', 'Q14A', 'Q15A', 'Q16A', 'Q17A', 'Q18A', 'Q19A', 'Q20A', 'Q21A',
           'Q22A', 'Q23A', 'Q24A', 'Q25A', 'Q26A', 'Q27A', 'Q28A', 'Q29A', 'Q30A', 'Q31A',
           'Q32A', 'Q33A', 'Q34A', 'Q35A', 'Q36A', 'Q37A', 'Q38A', 'Q39A', 'Q40A', 'Q41A',
           'Q42A']] = new_data[['Q1A', 'Q2A', 'Q3A', 'Q4A', 'Q5A', 'Q6A', 'Q7A', 'Q8A', 'Q9A', 'Q10A', 'Q11A',
                                 'Q12A', 'Q13A', 'Q14A', 'Q15A', 'Q16A', 'Q17A', 'Q18A', 'Q19A', 'Q20A', 'Q21A',
                                 'Q22A', 'Q23A', 'Q24A', 'Q25A', 'Q26A', 'Q27A', 'Q28A', 'Q29A', 'Q30A', 'Q31A',
                                 'Q32A', 'Q33A', 'Q34A', 'Q35A', 'Q36A', 'Q37A', 'Q38A', 'Q39A', 'Q40A', 'Q41A',
                                 'Q42A']].applymap({1: 0, 2: 1, 3: 2, 4: 3}.get)

# %%
new_data['Q1A'].unique()
# Out:
# array([3, 2, 1, 0])

# %% [markdown]
# now we will make 3 different datasets for Depression, Anxiety and Stress

# %% [markdown]
# Depression: 3, 5, 10, 13, 16, 17, 21, 24, 26, 31, 34, 37, 38, 42
#
# Anxiety: 2, 4, 7, 9, 15, 19, 20, 23, 25, 28, 30, 36, 40, 41
#
# Stress: 1, 6, 8, 11, 12, 14, 18, 22, 27, 29, 32, 33, 35, 39
#
#
# and rest of the columns will be common in all three datasets

# %%
Depression = [3, 5, 10, 13, 16, 17, 21, 24, 26, 31, 34, 37, 38, 42]

Anxiety =  [2, 4, 7, 9, 15, 19, 20, 23, 25, 28, 30, 36, 40, 41]

Stress = [1, 6, 8, 11, 12, 14, 18, 22, 27, 29, 32, 33, 35, 39]

# %% [markdown]
# ## Depression

# %%
depression = new_data[['Q3A', 'Q5A', 'Q10A', 'Q13A', 'Q16A', 'Q17A', 'Q21A', 'Q24A', 'Q26A', 'Q31A', 'Q34A', 'Q37A', 'Q38A', 'Q42A', 'TIPI1', 'TIPI2', 'TIPI3',
       'TIPI4', 'TIPI5', 'TIPI6', 'TIPI7', 'TIPI8', 'TIPI9', 'TIPI10',
       'education', 'urban', 'gender', 'married', 'familysize', 'age_group']]

depression['total_count'] = new_data[[f'Q{i}A' for i in Depression]].sum(axis = 1)
# Out:
# <ipython-input-137-b441ea3b14a0>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   depression['total_count'] = new_data[[f'Q{i}A' for i in Depression]].sum(axis = 1)

# %%
depression.head()
# Out:
#    Q3A  Q5A  Q10A  Q13A  Q16A  Q17A  Q21A  Q24A  Q26A  Q31A  ...  TIPI8  \
# 0    1    3     0     3     3     2     0     3     3     3  ...      5
# 1    1    3     1     3     2     3     1     1     2     1  ...      7
# 2    3    3     3     3     3     3     3     3     0     3  ...      5
# 3    1    2     2     0     1     2     0     0     1     2  ...      1
# 4    2    3     2     3     2     3     2     1     3     2  ...      6
#
#    TIPI9  TIPI10  education  urban  gender  married  familysize  age_group  \
# 0      1       1          2      3       2        1           2          2
# 1      1       5          2      3       2        1           4          2
# 2      3       2          2      3       2        1           3          3
# 3      6       1          1      3       2        1           5          2
# 4      3       3          3      2       2        1           4          3
#
#    total_count
# 0           27
# 1           24
# 2           39
# ...

# %%
plt.figure(figsize=(10, 5))
sns.histplot(x=depression['total_count'])
# Out:
# <Axes: xlabel='total_count', ylabel='Count'>

# %%
depression[depression['total_count'] < 10]['total_count'].count()
# Out:
# 8846

# %%
depression['total_count'].describe()
# Out:
# count    39733.00000
# mean        21.05995
# std         12.32129
# min          0.00000
# 25%         11.00000
# 50%         21.00000
# 75%         32.00000
# max         42.00000
# Name: total_count, dtype: float64

# %%
def buildlabel_depression(value):
    if value <= 9:
        return 'Normal'
    if 10 <= value <= 13:
        return 'Mild'
    if 14 <= value <= 20:
        return 'Moderate'
    if 21 <= value <= 27:
        return 'Severe'
    if value > 27:
        return 'Extremely Severe'

depression['target'] = depression['total_count'].apply(buildlabel_depression)
# Out:
# <ipython-input-142-4b53f85ab087>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   depression['target'] = depression['total_count'].apply(buildlabel_depression)

# %%
sns.countplot(x=depression['target'])
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pickle

# %%
target_depression = depression['target']
depression.drop(['target', 'total_count'], axis=1, inplace = True)
# Out:
# <ipython-input-145-ae66c296dccd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   depression.drop(['target', 'total_count'], axis=1, inplace = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(depression, target_depression, test_size=0.3, random_state=42)
print(f'x_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'x_test: {X_test.shape}, y_test: {y_test.shape}')
# Out:
# x_train: (27813, 30), y_train: (27813,)
# x_test: (11920, 30), y_test: (11920,)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_d = StandardScaler()

X_train = scaler_d.fit_transform(X_train)
X_test = scaler_d.transform(X_test)

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(),
    'Support Vector Classifier' : SVC(),
    'Decision Tree Classifier' : DecisionTreeClassifier()
}

# Train and evaluate models
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    results[name] = accuracy

# Print results
for name, accuracy in results.items():
    print(f'{name}: Accuracy = {accuracy:.2f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression: Accuracy = 1.00
# Random Forest: Accuracy = 0.92
# Support Vector Classifier: Accuracy = 0.98
# Decision Tree Classifier: Accuracy = 0.79

# %% [markdown]
# since logistic regression is showing overfit, we will be using the SVC for our prediction purpose.

# %%
svc_d = SVC()
svc_d.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pre_d = svc_d.predict(X_test)

# %%
acc_d = accuracy_score(y_test, y_pre_d)

# %%
acc_d
# Out:
# 0.9834731543624161

# %%
with open('model_d.pkl', 'wb') as model_file:
    pickle.dump({"model": svc_d, "scaler": scaler_d}, model_file)

# %% [markdown]
# ## Anxiety

# %%
[f'Q{i}A' for i in Anxiety]
# Out:
# ['Q2A',
#  'Q4A',
#  'Q7A',
#  'Q9A',
#  'Q15A',
#  'Q19A',
#  'Q20A',
#  'Q23A',
#  'Q25A',
#  'Q28A',
#  'Q30A',
#  'Q36A',
#  'Q40A',
#  'Q41A']

# %%
anxiety = new_data[['Q2A','Q4A','Q7A','Q9A','Q15A','Q19A','Q20A','Q23A','Q25A','Q28A','Q30A','Q36A','Q40A','Q41A', 'TIPI1', 'TIPI2', 'TIPI3',
       'TIPI4', 'TIPI5', 'TIPI6', 'TIPI7', 'TIPI8', 'TIPI9', 'TIPI10',
       'education', 'urban', 'gender', 'married', 'familysize', 'age_group']]

anxiety['total_count'] = new_data[[f'Q{i}A' for i in Anxiety]].sum(axis = 1)
# Out:
# <ipython-input-155-e5152608d77d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anxiety['total_count'] = new_data[[f'Q{i}A' for i in Anxiety]].sum(axis = 1)

# %%
anxiety.head()
# Out:
#    Q2A  Q4A  Q7A  Q9A  Q15A  Q19A  Q20A  Q23A  Q25A  Q28A  ...  TIPI8  TIPI9  \
# 0    3    3    3    1     3     2     2     3     3     2  ...      5      1
# 1    0    2    2    2     2     0     0     0     1     3  ...      7      1
# 2    0    0    0    1     3     1     0     1     1     0  ...      5      3
# 3    2    0    3    2     1     0     1     0     0     0  ...      1      6
# 4    1    3    3    3     3     3     3     3     3     3  ...      6      3
#
#    TIPI10  education  urban  gender  married  familysize  age_group  \
# 0       1          2      3       2        1           2          2
# 1       5          2      3       2        1           4          2
# 2       2          2      3       2        1           3          3
# 3       1          1      3       2        1           5          2
# 4       3          3      2       2        1           4          3
#
#    total_count
# 0           34
# 1           17
# 2           12
# 3           17
# ...

# %%
anxiety['total_count'].describe()
# Out:
# count    39733.000000
# mean        16.054061
# std         10.248115
# min          0.000000
# 25%          8.000000
# 50%         15.000000
# 75%         23.000000
# max         42.000000
# Name: total_count, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.histplot(x=anxiety['total_count'])
# Out:
# <Axes: xlabel='total_count', ylabel='Count'>

# %%
def buildlabel_anxiety(value):
    if value <= 7:
        return 'Normal'
    if 8 <= value <= 9:
        return 'Mild'
    if 10 <= value <= 14:
        return 'Moderate'
    if 15 <= value <= 19:
        return 'Severe'
    if value > 19:
        return 'Extremely Severe'


anxiety['target'] = anxiety['total_count'].apply(buildlabel_anxiety)
# Out:
# <ipython-input-159-b36831e70e3b>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anxiety['target'] = anxiety['total_count'].apply(buildlabel_anxiety)

# %%
sns.countplot(x=anxiety['target'])
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
target_anxiety = anxiety['target']
anxiety.drop(['target', 'total_count'], axis=1, inplace = True)
# Out:
# <ipython-input-161-ee4514d77152>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   anxiety.drop(['target', 'total_count'], axis=1, inplace = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(anxiety, target_anxiety, test_size=0.3, random_state=42)
print(f'x_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'x_test: {X_test.shape}, y_test: {y_test.shape}')
# Out:
# x_train: (27813, 30), y_train: (27813,)
# x_test: (11920, 30), y_test: (11920,)

# %%
scaler_a = StandardScaler()

X_train = scaler_a.fit_transform(X_train)
X_test = scaler_a.transform(X_test)

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(),
    'Support Vector Classifier' : SVC(),
    'Decision Tree Classifier' : DecisionTreeClassifier()
}

# Train and evaluate models
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    results[name] = accuracy

# Print results
for name, accuracy in results.items():
    print(f'{name}: Accuracy = {accuracy:.2f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression: Accuracy = 1.00
# Random Forest: Accuracy = 0.86
# Support Vector Classifier: Accuracy = 0.99
# Decision Tree Classifier: Accuracy = 0.73

# %%
svc_a = SVC()
svc_a.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pre_a = svc_a.predict(X_test)

# %%
acc_a = accuracy_score(y_test, y_pre_a)

# %%
acc_a
# Out:
# 0.9875

# %%
with open('model_a.pkl', 'wb') as model_file:
    pickle.dump({"model": svc_a, "scaler": scaler_a}, model_file)

# %% [markdown]
# ## Stress

# %%
[f'Q{i}A' for i in Stress]
# Out:
# ['Q1A',
#  'Q6A',
#  'Q8A',
#  'Q11A',
#  'Q12A',
#  'Q14A',
#  'Q18A',
#  'Q22A',
#  'Q27A',
#  'Q29A',
#  'Q32A',
#  'Q33A',
#  'Q35A',
#  'Q39A']

# %%
stress = new_data[['Q1A','Q6A','Q8A','Q11A','Q12A','Q14A','Q18A','Q22A','Q27A','Q29A','Q32A','Q33A','Q35A','Q39A','Q41A', 'TIPI1', 'TIPI2', 'TIPI3',
       'TIPI4', 'TIPI5', 'TIPI6', 'TIPI7', 'TIPI8', 'TIPI9', 'TIPI10',
       'education', 'urban', 'gender', 'married', 'familysize', 'age_group']]

stress['total_count'] = new_data[[f'Q{i}A' for i in Stress]].sum(axis = 1)
# Out:
# <ipython-input-177-6ebd66fa3252>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stress['total_count'] = new_data[[f'Q{i}A' for i in Stress]].sum(axis = 1)

# %%
stress.head()
# Out:
#    Q1A  Q6A  Q8A  Q11A  Q12A  Q14A  Q18A  Q22A  Q27A  Q29A  ...  TIPI8  TIPI9  \
# 0    3    3    3     3     3     3     3     3     3     3  ...      5      1
# 1    3    3    3     1     1     3     1     2     2     2  ...      7      1
# 2    2    2    2     1     0     0     1     2     1     1  ...      5      3
# 3    1    2    1     1     0     3     0     0     3     2  ...      1      6
# 4    1    1    3     1     3     3     3     2     1     1  ...      6      3
#
#    TIPI10  education  urban  gender  married  familysize  age_group  \
# 0       1          2      3       2        1           2          2
# 1       5          2      3       2        1           4          2
# 2       2          2      3       2        1           3          3
# 3       1          1      3       2        1           5          2
# 4       3          3      2       2        1           4          3
#
#    total_count
# 0           40
# 1           27
# 2           17
# 3           16
# ...

# %%
stress['total_count'].describe()
# Out:
# count    39733.000000
# mean        21.154179
# std         10.523259
# min          0.000000
# 25%         13.000000
# 50%         21.000000
# 75%         29.000000
# max         42.000000
# Name: total_count, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.histplot(x=stress['total_count'])
# Out:
# <Axes: xlabel='total_count', ylabel='Count'>

# %%
def buildlabel_stress(value):
    if value <= 14:
        return 'Normal'
    if 15 <= value <= 18:
        return 'Mild'
    if 19 <= value <= 25:
        return 'Moderate'
    if 26 <= value <= 33:
        return 'Severe'
    if value > 33:
        return 'Extremely Severe'


stress['target'] = stress['total_count'].apply(buildlabel_stress)
# Out:
# <ipython-input-181-df54141bbd55>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stress['target'] = stress['total_count'].apply(buildlabel_stress)

# %%
sns.countplot(x=stress['target'])
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
target_stress = stress['target']
stress.drop(['target', 'total_count'], axis=1, inplace = True)
# Out:
# <ipython-input-183-aac9f9c05046>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stress.drop(['target', 'total_count'], axis=1, inplace = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(stress, target_stress, test_size=0.3, random_state=42)
print(f'x_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'x_test: {X_test.shape}, y_test: {y_test.shape}')
# Out:
# x_train: (27813, 31), y_train: (27813,)
# x_test: (11920, 31), y_test: (11920,)

# %%
scaler_s = StandardScaler()

X_train = scaler_s.fit_transform(X_train)
X_test = scaler_s.transform(X_test)

# %%
models = {
    'Logistic Regression': LogisticRegression(),
    'Random Forest': RandomForestClassifier(),
    'Support Vector Classifier' : SVC(),
    'Decision Tree Classifier' : DecisionTreeClassifier()
}

# Train and evaluate models
results = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    results[name] = accuracy

# Print results
for name, accuracy in results.items():
    print(f'{name}: Accuracy = {accuracy:.2f}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression: Accuracy = 1.00
# Random Forest: Accuracy = 0.90
# Support Vector Classifier: Accuracy = 0.99
# Decision Tree Classifier: Accuracy = 0.73

# %%
svc_s = SVC()
svc_s.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pre_s = svc_s.predict(X_test)

# %%
acc_s = accuracy_score(y_test, y_pre_s)

# %%
acc_s
# Out:
# 0.9859060402684564

# %%
with open('model_s.pkl', 'wb') as model_file:
    pickle.dump({"model": svc_s, "scaler": scaler_s}, model_file)
